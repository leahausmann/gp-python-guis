# %% [markdown]
# # ÜBUNGSAUFGABE zu CustomTkinter
#
# 1. Erstelle das Hauptfenster mit dem Titel Übung CTk in den Maßen 400x800
# 2. Stelle den Darkmode ein
# 3. Füge einen Button und ein Eingabefeld hinzu, welche jeweils einen Abstand von 10 Pixel nach oben und unten haben.

# %%
import customtkinter as ctk







app.mainloop()
