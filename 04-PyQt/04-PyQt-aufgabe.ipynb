# %% [markdown]
# ### Hinweis
#
# Damit der Code funktioniert, muss PyQt6 installiert sein:
#
# > `pip install PyQt6`
#
# ---
#
# # 06 PyQt – Übung (mit Codevorlage)
#
# In dieser Übung ergänzt du ein kleines PyQt-Programm.
# Das Ziel ist, dass der Benutzer Text eingibt und dieser nach einem Klick auf den Button in einem Label angezeigt wird.
#
# ## Aufgabe
#
# Ergänze den vorgegebenen Code so, dass:
#
# 1. ein **horizontales Layout** (`QHBoxLayout`) verwendet wird,
# 2. der Button das Signal `clicked` sendet,
# 3. eine Funktion ausgeführt wird, die den eingegebenen Text in das Label schreibt.

# %%
from PyQt6.QtWidgets import QApplication, QWidget, QLabel, QPushButton, QLineEdit, QHBoxLayout
import sys


class PyQtExerciseWindow(QWidget):
    def __init__(self):
        super().__init__()

        self.setWindowTitle("PyQt Übung")
        self.label = QLabel("Gib einen Text ein:")
        self.text_input = QLineEdit()
        self.button = QPushButton("Anzeigen")

        # TODO: Erstelle hier ein QVBoxLayout
        # layout = ?

        # TODO: Füge Label, Eingabefeld und Button zum Layout hinzu

        # TODO: Verbinde den Button mit der Funktion update_label

    def update_label(self):
        # TODO: Lies den Text aus dem Eingabefeld
        # TODO: Schreibe den Text in das Label
        pass


def main():
    app = QApplication(sys.argv)
    window = PyQtExerciseWindow()
    window.show()
    sys.exit(app.exec())


if __name__ == "__main__":
    main()
